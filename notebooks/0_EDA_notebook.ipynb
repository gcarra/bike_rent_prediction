# %%
# %reload_ext autoreload
# %autoreload 2

# %%
#from src.data_load import download_dataset
from src.path import DATA_DIR
from src.data_preprocessing import *
from src.models import *
#download_dataset()

# %%
from src.path import DATA_DIR
import pandas as pd

raw_data = pd.read_csv(DATA_DIR / "raw_data.csv")  

# Print important informations
print(f'There are {raw_data.isnull().any().sum()} null values' )
print('The dataset contains the following features:')
print(raw_data.columns)
raw_data.head()
# Out:
# There are 0 null values
# The dataset contains the following features:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# ...

# %% [markdown]
# -> Il n'y a pas de null data mais en supposant que mon data set est mis à jour chaque jour, quel type de transformation je ferais automatiquement ?
# **Avant de repondre à cette question peut-être pertinent d'analyser quelles variables je vais garder pour la modelisation et me poser la question que sur les variables restantes**
#
# **Voir s'il y a une façon automatique de faire la feature selection que je pourrais regulierement faire tourner pour verifier qu'il n'y a pas eu un changement dans les features importantes**
#
#
#
# **Check for outliers**
# > check for normal distrbution otherwise use median definition and decide to eliminate outliers for the moment without trying to understand why we have it
#
# **Verifiy data value**
# > week ok
# > season ok

# %%
raw_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# Feature engineering 1: from the feature "datetime" we create four other features: year, month, day, hour 
raw_data["datetime"] = pd.to_datetime(raw_data["datetime"])
raw_data['Year'] = pd.to_datetime(raw_data['datetime']).dt.year
raw_data['Month'] = pd.to_datetime(raw_data['datetime']).dt.month
raw_data['Day'] =  pd.to_datetime(raw_data['datetime']).dt.weekday
raw_data['Hour'] = pd.to_datetime(raw_data['datetime']).dt.hour

# %%
from src.data_preprocessing import *

features, target = cleaning_data(raw_data)
features.head()
# Out:
#              datetime  season  holiday  workingday weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1    False       False       1  9.84  14.395
# 1 2011-01-01 01:00:00       1    False       False       1  9.02  13.635
# 2 2011-01-01 02:00:00       1    False       False       1  9.02  13.635
# 3 2011-01-01 03:00:00       1    False       False       1  9.84  14.395
# 4 2011-01-01 04:00:00       1    False       False       1  9.84  14.395
#
#    humidity  windspeed  casual  registered
# 0        81        0.0       3          13
# 1        80        0.0       8          32
# 2        80        0.0       5          27
# 3        75        0.0       3          10
# 4        75        0.0       0           1

# %%
feature_preprocess = feature_engineering()

# %%
features = feature_preprocess.define_exra_features(features)

# %%
features = feature_preprocess.transform_cyclical_values(features)

# %%
features = feature_preprocess.drop_cols(features)

# %%
preprocessor = get_preprocessor_pipeline()

# %%
len(X_temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 len(X_temp)
#
# NameError: name 'X_temp' is not defined

# %%
y_train.head()
# Out:
#              datetime  season  holiday  workingday weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1    False       False       1  9.84  14.395
# 1 2011-01-01 01:00:00       1    False       False       1  9.02  13.635
# 2 2011-01-01 02:00:00       1    False       False       1  9.02  13.635
# 3 2011-01-01 03:00:00       1    False       False       1  9.84  14.395
# 4 2011-01-01 04:00:00       1    False       False       1  9.84  14.395
#
#    humidity  windspeed  casual  registered  Year  Month  Day  Hour
# 0        81        0.0       3          13  2011      1    5     0
# 1        80        0.0       8          32  2011      1    5     1
# 2        80        0.0       5          27  2011      1    5     2
# 3        75        0.0       3          10  2011      1    5     3
# 4        75        0.0       0           1  2011      1    5     4

# %%
X_temp = features_train.copy()
y_train = target_train.copy()
X_temp["weekday"] = (X_temp["datetime"]).dt.weekday
Xy = X_temp.join(y_train)
predictor = Xy.groupby("weekday")["count"].median().reset_index() 
weekday = features_test["datetime"].dt.weekday
predictor["weekday"] == weekday
#predictor.loc[predictor["weekday"] == weekday]["count"].item()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[210], line 7
#       5 predictor = Xy.groupby("weekday")["count"].median().reset_index()
#       6 weekday = features_test["datetime"].dt.weekday
# ----> 7 predictor["weekday"] == weekday
#       8 #predictor.loc[predictor["weekday"] == weekday]["count"].item()
#
# File ~/bike_rent/.venv/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/bike_rent/.venv/lib/python3.10/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
features, target = cleaning_data(raw_data)

(features_train, 
features_test,
target_train,
target_test) = split_data(features, target, 0.8)

preprocessor = get_preprocessor_pipeline()
model = BaselineModel()
model.fit(features_train, target_train)
predictions = model.predict(features_test)

test_mae = mean_absolute_error(target_test, predictions)
mean_count = target_test.mean()
print(f'{test_mae=:.4f}')
print(f'{mean_count}')
# Out:
# test_mae=187.4929
# 260.2741046831956
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
target_test.head()
# Out:
# 8708     19
# 8709     19
# 8710     68
# 8711    108
# 8712    229
# Name: count, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error

features, target = cleaning_data(raw_data)
features = feature_engineering(features)

(features_train, features_test,
target_train,
target_test) = split_data(features, target, 0.8)

model = xgb.XGBRegressor(enable_categorical = True)
model.fit(features_train, target_train)
predictions = model.predict(features_test)

test_mae = mean_absolute_error(target_test, predictions)
mean_count = target_test.mean()
print(f'{test_mae=:.4f}')
print(f'{mean_count}')
# Out:
# test_mae=46.8573
# 260.2741046831956

# %%
from sklearn.metrics import mean_absolute_error
from src.ML_pipeline import *

features, target = cleaning_data(raw_data)
features = feature_engineering(features)

(features_train, features_test,
target_train,
target_test) = split_data(features, target, 0.8)

xbg_pipeline = get_xgb_pipeline(enable_categorical = True)
xbg_pipeline.fit(features_train, target_train)
predictions = xbg_pipeline.predict(features_test)

test_mae = mean_absolute_error(target_test, predictions)
mean_count = target_test.mean()
print(f'{test_mae=:.4f}')
print(f'{mean_count}')
# Out:
# test_mae=48.8758
# 260.2741046831956
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
from sklearn.ensemble import RandomForestRegressor

features, target = cleaning_data(raw_data)
#features = feature_engineering(features)
rfr_model = RandomForestRegressor(n_jobs=-1, n_estimators = 1000, max_depth = 40) 
rfr_model.(features_train, target_train)
predictions = rfr_model.predict(features_test)
predictions_train = rfr_model.predict(features_train)

test_mae = mean_absolute_error(target_test, predictions)
mean_count = target_test.mean()
print(f'{test_mae=:.4f}')
print(f'{mean_count}')

test_mae = mean_absolute_error(target_train, predictions_train)
mean_count = target_train.mean()
print(f'{test_mae=:.4f}')
print(f'{mean_count}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[253], line 6
#       4 #features = feature_engineering(features)
#       5 rfr_model = RandomForestRegressor(n_jobs=-1, n_estimators = 1000, max_depth = 40)
# ----> 6 rfr_model.train(features_train, target_train)
#       7 predictions = rfr_model.predict(features_test)
#       8 predictions_train = rfr_model.predict(features_train)
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'train'

# %%
from sklearn.metrics import mean_absolute_error
from src.ML_pipeline import *

features, target = cleaning_data(raw_data)
features = feature_engineering(features)

(features_train, features_test,
target_train,
target_test) = split_data(features, target, 0.8)


LGBM_pipeline = get_LGBM_pipeline(num_leaves = 30 , max_depth = 20, min_data_in_leaf = 40, learning_rate = 0.05, n_estimators = 500,force_row_wise=True)
LGBM_pipeline.fit(features_train, target_train)
predictions = LGBM_pipeline.predict(features_test)

test_mae = mean_absolute_error(target_test, predictions)
mean_count = target_test.mean()
print(f'{test_mae=:.4f}')
print(f'{mean_count}')
# Out:
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Warning] min_data_in_leaf is set=40, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=40
# [LightGBM] [Info] Total Bins 225
# [LightGBM] [Info] Number of data points in the train set: 8708, number of used features: 16
# [LightGBM] [Info] Start training from score 174.391249
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from src.ML_pipeline import *

features, target = cleaning_data(raw_data)
features = feature_engineering(features)

(features_train, features_test,
target_train,
target_test) = split_data(features, target, 0.8)

LGBM_model = lgb.LGBMRegressor(num_leaves = 30 , max_depth = 20, min_data_in_leaf = 40, learning_rate = 0.05, n_estimators = 500 ,force_row_wise=True)
LGBM_model.fit(features_train, target_train)
predictions = LGBM_model.predict(features_test)

test_mae = mean_absolute_error(target_test, predictions)
test_mse = mean_squared_error(target_test, predictions)
mean_count = target_test.mean()
print(f'{test_mae=:.4f}')
print(f'{test_mse=:.4f}')
print(f'{mean_count}')
# Out:
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[291], line 13
#      10 grid = GridSearchCV(model, param_grid, cv=2, scoring='neg_mean_absolute_error')
#      12 # Perform grid search to find the best combination of hyperparameters
# ---> 13 grid.fit(features_train, target_train)
#      15 # Print the best parameters found by the grid search
# ...

# %%
from sklearn.metrics import mean_absolute_error
from src.ML_pipeline import *

features, target = cleaning_data(raw_data)
features = feature_engineering(features)

(features_train, features_test,
target_train,
target_test) = split_data(features, target, 0.8)



# Import necessary libraries
from sklearn.model_selection import GridSearchCV
import numpy as np

# Define a parameter grid for hyperparameter tuning
param_grid = {
    'num_leaves': [45, 50, 55],           # Number of leaves in each tree
    'min_data_in_leaf':  [15, 20, 25],
    'max_depth' : [30 ,50, 60],
    'learning_rate': [0.03, 0.05, 0.08],   # Learning rate for gradient boosting
    'n_estimators': [500]         # Number of boosting iterations
}

# Create a LightGBM classifier instance with specified settings
gbm = lgb.LGBMRegressor( force_row_wise=True)

# Create a GridSearchCV object with specified settings
grid = GridSearchCV(gbm, param_grid, cv=2, scoring='neg_mean_absolute_error')

# Perform grid search to find the best combination of hyperparameters
grid.fit(features_train, target_train)

# Print the best parameters found by the grid search
print('Best parameters found by grid search are:', grid.best_params_)







# LGBM_model = lgb.LGBMRegressor(force_row_wise=True)
# LGBM_model.test(features_train, target_train)
# predictions = LGBM_model.predict(features_test)

# test_mae = mean_absolute_error(target_test, predictions)
# mean_count = target_test.mean()
# print(f'{test_mae=:.4f}')
# print(f'{mean_count}')
# Out:
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# /home/gcarra/bike_rent/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Info] Total Bins 218
# [LightGBM] [Info] Number of data points in the train set: 4354, number of used features: 12
# [LightGBM] [Info] Start training from score 205.941203
# ...
